# %%
# !pip install PdfPlumber

# %% [markdown]
# **View PDF page as an image**

# %%
import pdfplumber

pdf_path = "PDFs/NPP 2025 English .pdf"
all_text = ""

with pdfplumber.open(pdf_path) as pdf:
    all_text = pdf.pages[0].extract_text()

im = pdf.pages[5].to_image()
im

# %% [markdown]
# **Opening a PDF and getting data in all pages**

# %%
import pdfplumber

with pdfplumber.open("PDFs/NPP 2025 English .pdf") as pdf:
    for page_num, page in enumerate(pdf.pages, start=1):
        text = page.extract_text()
        print(f"\n--- Page {page_num} ---\n")
        print(text)
# Out:
# --- Page 1 ---
#
#
#
# --- Page 2 ---
#
#
#
# --- Page 3 ---
#
# Content
# 1. A fulfilling life - A comfortable country ..................................................................................... 1
# 1.1 A civilized citizen - An advanced human resource ................................................................. 2
# 1.2 A vigorous life - Healthy people ............................................................................................. 9
# 1.3 A comfortable home - A healthy living ................................................................................ 14
# 1.4 An energetic citizen - Triumphant people ............................................................................. 16
# 1. 5 A rich cultural life - A compassionate society ...................................................................... 19
# 1.6 A conserved history - Innovating across heritage .................................................................. 25
# ...
